# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

import numpy as np
import pandas as pd

# %% [markdown]
# Méthode 1 : Récupérer champ par champ

# %%
# Url / set a list of URLS later
url = "https://www.booking.com/hotel/fr/disney-39-s-newport-bay-club-r.fr.html#tab-reviews"

# Get the driver
driver = webdriver.Chrome("/usr/local/bin/chromedriver")

# Create list to get the data
collectName = []
collectCountry = []
collectType_room = []
collectLen_reservation = []
collectMonth_year = []
collectVoyageur_info = []
collectDate_review = []
collectReview_title = []
collectGrade_review = []
collectPositive_review = []
collectNegative_review = []
collectIs_review_usefull = []
collectUniqueID = []

chiffres = list("0123456789")

# Put the url into the driver
driver.get(url)

time.sleep(2)
# Reject cookies
driver.find_element(By.ID, "onetrust-reject-all-handler").click()

driver.find_element(By.XPATH, '//*[@id="review_sort"]/option[2]').click()
time.sleep(2)

n_pages = driver.find_element(By.XPATH, '//*[@id="review_list_page_container"]/div[4]/div/div[1]/div/div[2]/div/div[7]/a/span[1]').text
n_pages = int(n_pages)

for p in range(1,n_pages+1):
    
    time.sleep(2)

    for i in range(1,11):
        
        time.sleep(1)

        # Nom voyageur
        name_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[1]/div[1]/div/div[2]/span[1]'
        try:
            name = driver.find_element(By.XPATH, name_path).text
        except:
            name = None
        collectName.append(name)

        # Pays voyageur
        country_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[1]/div[1]/div/div[2]/span[2]'
        try:
            country = driver.find_element(By.XPATH, country_path).text
        except:
            country = None
        collectCountry.append(country)

        # Type de chambre
        type_room_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[1]/div[2]/ul/li/a'
        
        try: 
            type_room = driver.find_element(By.XPATH, type_room_path).text
        except:
            type_room = None
        collectType_room.append(type_room)

        # Nuitées
        len_reservation_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[1]/ul[1]/li/div'
        try:
            len_reservation = driver.find_element(By.XPATH, len_reservation_path).text
        except:
            len_reservation = None
        collectLen_reservation.append(len_reservation[0])

        # Mois année du voyage
        month_year_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[1]/ul[1]/li/div/span'
        try:
            month_year = driver.find_element(By.XPATH, month_year_path).text
        except:
            month_year = None
        collectMonth_year.append(month_year)

        # Informations voyageur
        voyageur_info_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[1]/ul[2]/li'
        try:
            voyageur_info = driver.find_element(By.XPATH, voyageur_info_path).text
        except:
            voyageur_info = None
        collectVoyageur_info.append(voyageur_info)

        # Date 
        date_review_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[2]/div[1]/span'
        date_review_path2 = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[2]/div[1]/span[2]'

        try:
            date_review = driver.find_element(By.XPATH, date_review_path).text
        except:
            date_review = None

        if date_review == 'Le choix des voyageurs' : 
        
            try:
                date_review = driver.find_element(By.XPATH, date_review_path2).text
            except:
                date_review = None
                
        collectDate_review.append(date_review)

        # Titre commentaire 
        review_title_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[2]/div[1]/div/div[1]/h3'
        try:
            review_title = driver.find_element(By.XPATH, review_title_path).text
        except:
            review_title = None
        collectReview_title.append(review_title)
        
        # Note
        grade_review_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[2]/div[1]/div/div[2]/div/div'
        try:
            grade_review = driver.find_element(By.XPATH, grade_review_path).text
        except:
            grade_review = None
        collectGrade_review.append(grade_review)

        # Commentaire positif
        positive_review_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[2]/div[2]/div/div[1]/p/span[3]'
        try:
            positive_review = driver.find_element(By.XPATH, positive_review_path).text
        except: 
            positive_review = None
        collectPositive_review.append(positive_review)
        
        # Commentaire négatif
        negative_review_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[2]/div[2]/div/div[2]/p/span[3]'
        try:
            negative_review = driver.find_element(By.XPATH, negative_review_path).text
        except:
            negative_review = None

        collectNegative_review.append(negative_review)

        # Utilité commentaire
        is_review_usefull_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[2]/div[3]/div/div[1]'
        try:
            is_review_usefull = driver.find_element(By.XPATH, is_review_usefull_path).text
        except:
            is_review_usefull = None
        collectIs_review_usefull.append(is_review_usefull)

        UniqueID = name + country + type_room + 
        
        collectUniqueID.append(UniqueID)
        
    # Changer de page    
    try:
        driver.find_element(By.CLASS_NAME, "pagenext").click()     
    except:
        pass
# Out:
# /var/folders/46/7rlt2f9x4szchbk_4z7ycdtc0000gn/T/ipykernel_4859/1695908872.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/usr/local/bin/chromedriver")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 75
#      73 except:
#      74     len_reservation = None
# ---> 75 collectLen_reservation.append(len_reservation[0])
#      77 # Mois année du voyage
#      78 month_year_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']/div/div[2]/div[1]/ul[1]/li/div/span'
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# Méthode 2 : Récupérer commentaire par commentaire

# %%
# Url / set a list of URLS later
url = "https://www.booking.com/hotel/fr/disney-39-s-newport-bay-club-r.fr.html#tab-reviews"

# Get the driver
driver = webdriver.Chrome("/usr/local/bin/chromedriver")

doc_review = []
# Put the url into the driver
driver.get(url)

# Reject cookies
driver.find_element(By.ID, "onetrust-reject-all-handler").click()

chiffres = list("0123456789")
n_pages = driver.find_element(By.XPATH, '//*[@id="review_list_page_container"]/div[4]/div/div[1]/div/div[2]/div').text
n_pages = n_pages[-5:]
n_pages = "".join([w for w in n_pages if w in chiffres])
n_pages = int(n_pages)

for p in range(1,n_pages+1):
    time.sleep(2)

    for i in range(1,11):
        full_review_path = '//*[@id="review_list_page_container"]/ul/li['+str(i)+']'
        try : 
            review = driver.find_element(By.XPATH,  full_review_path).text
        except:
            pass
        doc_review.append(review)

    try:
        driver.find_element(By.CLASS_NAME, "pagenext").click()  
    except:
        pass
# Out:
# C:\Users\houde\AppData\Local\Temp\ipykernel_19636\3196208583.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")

# %% [markdown]
# Méthode 3 : Récupérer page par page

# %%
# Url / set a list of URLS later
url = "https://www.booking.com/hotel/fr/disney-39-s-newport-bay-club-r.fr.html#tab-reviews"

# Get the driver
driver = webdriver.Chrome("/usr/local/bin/chromedriver")

doc_review = []
# Put the url into the driver
driver.get(url)

# Reject cookies
driver.find_element(By.ID, "onetrust-reject-all-handler").click()

chiffres = list("0123456789")
n_pages = driver.find_element(By.XPATH, '//*[@id="review_list_page_container"]/div[4]/div/div[1]/div/div[2]/div').text
n_pages = n_pages[-5:]
n_pages = "".join([w for w in n_pages if w in chiffres])
n_pages = int(n_pages)

for p in range(1,n_pages+1):
    time.sleep(2)

    full_page_path = '//*[@id="review_list_page_container"]/ul'
    try : 
        review = driver.find_element(By.XPATH,  full_review_path).text
    except:
        pass
    doc_review.append(review)

    try:
        driver.find_element(By.CLASS_NAME, "pagenext").click()  
    except:
        pass

# %% [markdown]
# Export :

# %% [markdown]
# Stockage du scrapping dans un fichier pickle (car peut exigeant à l'écriture) afin d'ouvrir les données sans avoir à scrapper à chaque fois (12 minutes pour la méthode 2, méthode 1 =  58 minutes)

# %%
# Python program to store list to file using pickle module
import pickle

# write list to binary file
def write_list(a_list):
    # store list in binary file so 'wb' mode
    with open('collectIs_review_usefull', 'wb') as fp:
        pickle.dump(collectIs_review_usefull, fp)
        print('Done writing list into a binary file')

# %% [markdown]
# Exporter les résultats

# %%
write_list(collectIs_review_usefull)
# Out:
# Done writing list into a binary file

# %% [markdown]
# Importer les données sauvegardées

# %%
import pickle
# Read list to memory
def read_list():
    # for reading also binary mode is important
    with open('scrapping', 'rb') as fp:
        n_list = pickle.load(fp)
        return n_list
        
scrapping = read_list()

# %%
Names = collectName
Country = collectCountry
room_type = collectType_room
nuitee = collectLen_reservation
reservation_date = collectMonth_year
traveler_infos = collectVoyageur_info
date_review = collectDate_review
review_title = collectReview_title
grade_review = collectGrade_review
positive_review = collectPositive_review
negative_review = collectNegative_review
usefulness_review = collectIs_review_usefull

columns = ['Names', 'Country', 'room_type', 'nuitee', 'reservation_date', 'traveler_infos', 'date_review', 'review_title', 'grade_review', 'positive_review', 'negative_review', 'usefulness_review']

df = pd.DataFrame(list(zip(Names, Country,room_type, nuitee, reservation_date, traveler_infos, date_review, review_title, grade_review, positive_review, negative_review, usefulness_review)), columns=columns)

# %%
df=df.assign(hotel="Disney's Newport Bay Club")

# %%
df.loc[(df.usefulness_review == 'Utile Pas utile'),'usefulness_review']='NaN'

# %%
df['usefulness_review'] = df['usefulness_review'].str[:2]

# %%
for i in range(2276) : 

    if df['usefulness_review'][i] == "Na":
        df['usefulness_review'][i] = 0

    if df['usefulness_review'][i] is None:
        df['usefulness_review'][i] = 0

# %%
df['usefulness_review'].value_counts()
# Out:
# 0     2032
# 1      164
# 2       57
# 3       14
# 6        3
# 5        2
# 7        2
# 4        1
# 9        1
# Name: usefulness_review, dtype: int64

# %%
df
# Out:
#          Names      Country                      room_type nuitee  \
# 0      Ludovic   La Réunion  Chambre Supérieure - Côté Lac      2
# 1       Julien       France             Chambre Supérieure      1
# 2       Celine       France             Chambre Supérieure      2
# 3        Diego       France             Chambre Supérieure      1
# 4     Fabienne     Belgique             Chambre Supérieure      1
# ...        ...          ...                            ...    ...
# 2271   Anonyme       Brésil                           None      2
# 2272   Anonyme  Royaume-Uni                           None      2
# 2273   Anonyme     Portugal                           None      2
# 2274   Anonyme        Japon                           None      3
# 2275   Anonyme        Japon                           None      2
#
#      reservation_date traveler_infos                             date_review  \
# 0        Octobre 2022        Famille    Commentaire envoyé le 9 octobre 2022
# 1       Décembre 2022         Couple  Commentaire envoyé le 15 décembre 2022
# 2       Décembre 2022        Famille  Commentaire envoyé le 14 décembre 2022
# 3       Novembre 2022        Famille  Commentaire envoyé le 30 novembre 2022
# 4       Novembre 2022        Famille  Commentaire envoyé le 18 novembre 2022
# ...               ...            ...                                     ...
# 2271     Janvier 2020        Famille   Commentaire envoyé le 14 janvier 2020
# 2272    Décembre 2019         Couple   Commentaire envoyé le 14 janvier 2020
# 2273     Janvier 2020         Couple   Commentaire envoyé le 13 janvier 2020
# 2274     Janvier 2020        Famille    Commentaire envoyé le 8 janvier 2020
# 2275    Décembre 2019         Groupe  Commentaire envoyé le 30 décembre 2019
#
#             review_title grade_review  \
# 0            Inoubliable           10
# 1              Très bien          8,0
# 2               Agréable          6,0
# 3               Agréable          6,0
# 4     déçue qualité prix          6,0
# ...                  ...          ...
# 2271        Exceptionnel           10
# 2272           Fabuleux           9,2
# 2273           Fabuleux           9,0
# 2274            Décevant          4,2
# 2275            Passable          5,0
#
#                                         positive_review  \
# 0     Le petit déjeuner et l'excellent buffet pour l...
# 1     Les navettes pour accéder au parc,\nLa taille ...
# 2                                                     Û
# 3                 la proximité du parc Disneyland Paris
# 4                                         l emplacement
# ...                                                 ...
# 2271                                               None
# 2272                                               None
# 2273                                               None
# 2274                                               None
# 2275                                               None
#
#                                         negative_review usefulness_review  \
# 0                                                  None                 0
# 1                                                 R.a.s                 0
# 2                                                  None                 0
# 3     la qualité de la chambre n’était pas top, vieu...                 0
# 4                                           la propreté                 0
# ...                                                 ...               ...
# 2271                                               None                 0
# 2272                                               None                 0
# 2273                                               None                 0
# 2274                                               None                 0
# 2275                                               None                 0
#
#                           hotel
# 0     Disney's Newport Bay Club
# 1     Disney's Newport Bay Club
# 2     Disney's Newport Bay Club
# 3     Disney's Newport Bay Club
# 4     Disney's Newport Bay Club
# ...                         ...
# 2271  Disney's Newport Bay Club
# 2272  Disney's Newport Bay Club
# 2273  Disney's Newport Bay Club
# 2274  Disney's Newport Bay Club
# 2275  Disney's Newport Bay Club
#
# [2276 rows x 13 columns]

# %%
df.to_csv(r'C:\Users\houde\Documents\GitHub\Disney-Text-Mining\Scrapping\Scrapping_Newport_Bay_Club_211222-2.csv', index = False, sep=';', encoding='utf-8')
