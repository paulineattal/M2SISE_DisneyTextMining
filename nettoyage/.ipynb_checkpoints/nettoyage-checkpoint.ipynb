# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
from dateutil import parser
import os
from os import listdir
from os.path import isfile, join
import psycopg2

# %%
conn = psycopg2.connect(user = "m140",password = "m140",host = "db-etu.univ-lyon2.fr",port = "5432",database = "m140")
try:
    cur = conn.cursor()
    history = "SELECT * FROM history"
    cur.execute(history)
    df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
except : 
    print ("Erreur lors de la récupération de la table PostgreSQL")
df.head()
# Out:
#         names      country                         room_type  nuitee  \
# 0       Sarva  Royaume-Uni  Chambre Standard Woody's Roundup       1
# 1     Aurelie       France  Chambre Standard Woody's Roundup       1
# 2       Chloé     Belgique  Chambre Standard Woody's Roundup       1
# 3      Hayley  Royaume-Uni  Chambre Standard Woody's Roundup       2
# 4  Emmanuelle       France  Chambre Standard Woody's Roundup       1
#
#   reservation_date traveler_infos                           date_review  \
# 0     Janvier 2023        Famille  Commentaire envoyé le 4 janvier 2023
# 1    Décembre 2022        Famille  Commentaire envoyé le 4 janvier 2023
# 2     Janvier 2023        Famille  Commentaire envoyé le 4 janvier 2023
# 3     Janvier 2023        Famille  Commentaire envoyé le 4 janvier 2023
# 4     Janvier 2023        Famille  Commentaire envoyé le 3 janvier 2023
#
#                        review_title grade_review  \
# 0           excellent and memorable          9,0
# 1                             Bien           7,0
# 2                             Bien           7,0
# 3    amazing and very helpful staff           10
# 4  On a passé un très bon moment !!          9,0
#
#                                      positive_review  \
# 0                                                NaN
# 1                             c’est proche de Disney
# 2                                                NaN
# 3                                                NaN
# 4  proximité du parc. décoration. propreté de la ...
#
#                                      negative_review  usefulness_review  \
# 0                                                NaN                  0
# 1                                         c’est cher                  0
# 2                                                NaN                  0
# 3                                                NaN                  0
# 4  la ventilation du chauffage qui faisait du bruit.                  0
#
#                                             uniqueid     hotel
# 0  SarvaRoyaume-UniChambre Standard Woody's Round...  Cheyenne
# 1  AurelieFranceChambre Standard Woody's RoundupD...  Cheyenne
# 2  ChloéBelgiqueChambre Standard Woody's RoundupJ...  Cheyenne
# 3  HayleyRoyaume-UniChambre Standard Woody's Roun...  Cheyenne
# 4  EmmanuelleFranceChambre Standard Woody's Round...  Cheyenne

# %%
#onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
#df = pd.DataFrame()

#for file in onlyfiles:
#    current_data = pd.read_csv(file, sep=';')  
#    df = pd.concat([df,current_data])
#df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Ajout dates

# %%
def clean_date_ajout(df):
    
    df_moisreview=df['date_review'].map(str)
    for i in range(df.shape[0]):
        df_moisreview[i]=df_moisreview[i].split()[4]
    df_moisreservation=df['reservation_date'].map(str)
    for i in range(df.shape[0]):
        df_moisreservation[i]=df_moisreservation[i].split()[0].lower()
        df_anneereservation=df['reservation_date'].map(str)
    for i in range(df.shape[0]):
        df_anneereservation[i]=df_anneereservation[i].split()[1]
        from time import strptime
    import locale
    locale.setlocale(locale.LC_TIME,'')

    list_mois_num = [strptime(moisreservation,'%B').tm_mon for moisreservation in df_moisreservation]
    list_mois_com = [strptime(moisreview,'%B').tm_mon for moisreview in df_moisreview]
    delai = [com - num if com-num>-1 else 12+(com-num) for com, num in zip(list_mois_com, list_mois_num)]

    d = {'month_str': df_moisreservation, 'month_num': list_mois_num, 'year' : df_anneereservation,  'delay_comment': delai}
    df_date = pd.DataFrame(data=d)
    df = pd.concat([df,df_date], join = 'outer', axis = 1)
    return(df)

# %%
def ajout_levels(df):
    conditionlist_note = [
    (df['grade_review'] >= 8) ,
    (df['grade_review'] > 5) & (df['grade_review'] <8),
    (df['grade_review'] <= 5)]
    choicelist_note = [2,1,0]
    df['level_grade_review'] = np.select(conditionlist_note, choicelist_note, default='Not Specified')
    conditionlist_hotel = [
    (df['hotel'] == "Newport_Bay_Club"),
    (df['hotel'] == "New_York"),
    (df['hotel'] == "Sequoia_Lodge"),
    (df['hotel'] == "Cheyenne"),
    (df['hotel'] == "Santa_Fe"),
    (df['hotel'] == "Davy_Crockett_Ranch")
    ]
    choicelist_hotel = [6,5,4,3,2,1]
    df['level_hotel'] = np.select(conditionlist_hotel, choicelist_hotel, default='Not Specified')
    return(df)

# %%
def recodage(df, var_tofloat):
    for i in var_tofloat:
        df[i] = df[i].str.replace(",",".")
        df[i] = pd.to_numeric(df[i], downcast="float")
    return(df)

# %%
df = recodage(df, ['grade_review'])

# %%
df = ajout_levels(df)

# %%
df['level_hotel'] = df['level_hotel'].astype(int)
df['level_grade_review'] = df['level_grade_review'].astype(int)

# %%
df = clean_date_ajout(df)

# %%
df = df.drop_duplicates(keep='first')

# %%
df.drop(df[(df.delay_comment >3)].index , inplace=True)

# %%
df=df.reset_index(drop=True)

# %%
df_date=df['date_review'].map(str)

# %%
for i in range(df.shape[0]):
    pos=df_date[i].find('le')
    #extraction
    df_date[i] = df_date[i][pos+2:] 
df['date_review']=df_date

# %%
df.head()
# Out:
#         Names      Country                         room_type  nuitee  \
# 0       Sarva  Royaume-Uni  Chambre Standard Woody's Roundup       1
# 1     Aurelie       France  Chambre Standard Woody's Roundup       1
# 2       Chloé     Belgique  Chambre Standard Woody's Roundup       1
# 3      Hayley  Royaume-Uni  Chambre Standard Woody's Roundup       2
# 4  Emmanuelle       France  Chambre Standard Woody's Roundup       1
#
#   reservation_date traveler_infos      date_review  \
# 0     Janvier 2023        Famille   4 janvier 2023
# 1    Décembre 2022        Famille   4 janvier 2023
# 2     Janvier 2023        Famille   4 janvier 2023
# 3     Janvier 2023        Famille   4 janvier 2023
# 4     Janvier 2023        Famille   3 janvier 2023
#
#                        review_title  grade_review  \
# 0           excellent and memorable           9.0
# 1                             Bien            7.0
# 2                             Bien            7.0
# 3    amazing and very helpful staff          10.0
# 4  On a passé un très bon moment !!           9.0
#
#                                      positive_review  \
# 0                                                NaN
# 1                             c’est proche de Disney
# 2                                                NaN
# 3                                                NaN
# 4  proximité du parc. décoration. propreté de la ...
#
#                                      negative_review  usefulness_review  \
# 0                                                NaN                  0
# 1                                         c’est cher                  0
# 2                                                NaN                  0
# 3                                                NaN                  0
# 4  la ventilation du chauffage qui faisait du bruit.                  0
#
#                                             UniqueID     hotel  \
# 0  SarvaRoyaume-UniChambre Standard Woody's Round...  Cheyenne
# 1  AurelieFranceChambre Standard Woody's RoundupD...  Cheyenne
# 2  ChloéBelgiqueChambre Standard Woody's RoundupJ...  Cheyenne
# 3  HayleyRoyaume-UniChambre Standard Woody's Roun...  Cheyenne
# 4  EmmanuelleFranceChambre Standard Woody's Round...  Cheyenne
#
#    level_grade_review  level_hotel month_str  month_num  year  delay_comment
# 0                   2            3   janvier          1  2023              0
# 1                   1            3  décembre         12  2022              1
# 2                   1            3   janvier          1  2023              0
# 3                   2            3   janvier          1  2023              0
# 4                   2            3   janvier          1  2023              0

# %%
def date_transform (mot):
    mot = mot.replace('janvier','january')
    mot = mot.replace('février','february')
    mot = mot.replace('mars','march')
    mot = mot.replace('avril','april')
    mot = mot.replace('mai','may')
    mot = mot.replace('juin','june')
    mot = mot.replace('juillet','july')
    mot = mot.replace('août','august')
    mot = mot.replace('septembre','september')
    mot = mot.replace('octobre','october')
    mot = mot.replace('novembre','november')
    mot = mot.replace('décembre','december')
    date=parser.parse(mot).date()
    return(date)

# %%
#df['date']=df['date_review'].apply(date_transform)
df["date"] = pd.to_datetime(dict(year=df.year, month=df.month_num, day=1))

# %%
df
# Out:
#             Names      Country  \
# 0           Sarva  Royaume-Uni
# 1         Aurelie       France
# 2           Chloé     Belgique
# 3          Hayley  Royaume-Uni
# 4      Emmanuelle       France
# ...           ...          ...
# 11214      Jacqui      Irlande
# 11215     Anonyme       France
# 11216      Celine       France
# 11217     Anonyme       France
# 11218     Gabriel       France
#
#                                                room_type  nuitee  \
# 0                       Chambre Standard Woody's Roundup       1
# 1                       Chambre Standard Woody's Roundup       1
# 2                       Chambre Standard Woody's Roundup       1
# 3                       Chambre Standard Woody's Roundup       2
# 4                       Chambre Standard Woody's Roundup       1
# ...                                                  ...     ...
# 11214  Chambre Golden Forest Club (2 Adultes + 2 Enfa...       3
# 11215                                                NaN       1
# 11216  Chambre Standard Proche des Installations Hôte...       2
# 11217                                                NaN       1
# 11218  Chambre Standard proche Installations Hôtelièr...       1
#
#       reservation_date traveler_infos      date_review  \
# 0         Janvier 2023        Famille   4 janvier 2023
# 1        Décembre 2022        Famille   4 janvier 2023
# 2         Janvier 2023        Famille   4 janvier 2023
# 3         Janvier 2023        Famille   4 janvier 2023
# 4         Janvier 2023        Famille   3 janvier 2023
# ...                ...            ...              ...
# 11214    Décembre 2019        Famille   4 janvier 2020
# 11215     Janvier 2020         Couple   4 janvier 2020
# 11216    Décembre 2019        Famille   4 janvier 2020
# 11217     Janvier 2020         Couple   3 janvier 2020
# 11218     Janvier 2020        Famille   3 janvier 2020
#
#                                             review_title  grade_review  \
# 0                                excellent and memorable           9.0
# 1                                                  Bien            7.0
# 2                                                  Bien            7.0
# 3                         amazing and very helpful staff          10.0
# 4                       On a passé un très bon moment !!           9.0
# ...                                                  ...           ...
# 11214  Would definitely stay again. Beautiful atmosph...           9.0
# 11215                                       Exceptionnel           9.6
# 11216                                       Exceptionnel          10.0
# 11217                                          Très bien           8.3
# 11218                Plutôt satisfaisant dans l'ensemble           8.0
#
#                                          positive_review  ...  \
# 0                                                    NaN  ...
# 1                                 c’est proche de Disney  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4         Janvier 2023        Famille   3 janvier 2023
# ...                ...            ...              ...
# 11214    Décembre 2019        Famille   4 janvier 2020
# 11215     Janvier 2020         Couple   4 janvier 2020
# 11216    Décembre 2019        Famille   4 janvier 2020
# 11217     Janvier 2020         Couple   3 janvier 2020
# 11218     Janvier 2020        Famille   3 janvier 2020
#
#                                             review_title  grade_review  \
# 0                                excellent and memorable           9.0
# 1                                                  Bien            7.0
# 2                                                  Bien            7.0
# 3                         amazing and very helpful staff          10.0
# 4                       On a passé un très bon moment !!           9.0
# ...                                                  ...           ...
# 11214  Would definitely stay again. Beautiful atmosph...           9.0
# 11215                                       Exceptionnel           9.6
# 11216                                       Exceptionnel          10.0
# 11217                                          Très bien           8.3
# 11218                Plutôt satisfaisant dans l'ensemble           8.0
#
#                                          positive_review  ...  \
# 0                                                    NaN  ...
# 1                                 c’est proche de Disney  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4      proximité du parc. décoration. propreté de la ...  ...
# ...                                                  ...  ...
# 11214                                                NaN  ...
# 11215                                                NaN  ...
# 11216                                                NaN  ...
# 11217                                                NaN  ...
# 11218  J'ai apprécié le cadre et 'l'hôtel au niveau d...  ...
#
#       usefulness_review                                           UniqueID  \
# 0                     0  SarvaRoyaume-UniChambre Standard Woody's Round...
# 1                     0  AurelieFranceChambre Standard Woody's RoundupD...
# 2                     0  ChloéBelgiqueChambre Standard Woody's RoundupJ...
# 3                     0  HayleyRoyaume-UniChambre Standard Woody's Roun...
# 4                     0  EmmanuelleFranceChambre Standard Woody's Round...
# ...                 ...                                                ...
# 11214                 1  JacquiIrlandeChambre Golden Forest Club (2 Adu...
# 11215                 0  AnonymeFrancenanJanvier 2020CoupleCommentaire ...
# 11216                 0  CelineFranceChambre Standard Proche des Instal...
# 11217                 0  AnonymeFrancenanJanvier 2020CoupleCommentaire ...
# 11218                 1  GabrielFranceChambre Standard proche Installat...
#
#                hotel level_grade_review  level_hotel  month_str month_num  \
# 0           Cheyenne                  2            3    janvier         1
# 1           Cheyenne                  1            3   décembre        12
# 2           Cheyenne                  1            3    janvier         1
# 3           Cheyenne                  2            3    janvier         1
# 4           Cheyenne                  2            3    janvier         1
# ...              ...                ...          ...        ...       ...
# 11214  Sequoia_Lodge                  2            4   décembre        12
# 11215  Sequoia_Lodge                  2            4    janvier         1
# 11216  Sequoia_Lodge                  2            4   décembre        12
# 11217  Sequoia_Lodge                  2            4    janvier         1
# 11218  Sequoia_Lodge                  2            4    janvier         1
#
#        year delay_comment       date
# 0      2023             0 2023-01-01
# 1      2022             1 2022-12-01
# 2      2023             0 2023-01-01
# 3      2023             0 2023-01-01
# 4      2023             0 2023-01-01
# ...     ...           ...        ...
# 11214  2019             1 2019-12-01
# 11215  2020             0 2020-01-01
# 11216  2019             1 2019-12-01
# 11217  2020             0 2020-01-01
# 11218  2020             0 2020-01-01
#
# [11219 rows x 21 columns]

# %%
df_clean.to_csv("C:/Users/cornuch/Documents/GitHub/Disney-Text-Mining/fichiers/df_clean/df_clean.csv",sep=';', index=False, encoding="utf-8-sig")
